# %% [markdown]
# ## Principles and Applications of Data Science (Spring 2020)
# ## Homework 1
# ## Due: Apr 22, 2020
#
# ### Name:
# ### Student ID Number:

# %% [markdown]
# # Step 1
# ### Use Pandas to load COVID-19 State Data Set as the dataframe.
# **[Pandas](https://pandas.pydata.org/)**
# **[COVID-19 State Data Set](https://www.kaggle.com/nightranger77/covid19-state-data/data)**

# %%
import pandas as pd
data = pd.read_csv("COVID19_state.csv")
# Out:
#         State  Tested  Infected  Deaths  Population  Pop Density    Gini  \
# 0      Alaska    5022       171     5.0      734002       1.2863  0.4081
# 1     Alabama   13078      1676    45.0     4908621      96.9221  0.4847
# 2    Arkansas   11143       819    14.0     3038999      58.4030  0.4719
# 3     Arizona   27160      2019    52.0     7378494      64.9550  0.4713
# 4  California  126700     12026   276.0    39937489     256.3727  0.4899
#
#    ICU Beds  Income    GDP  ...  Hospitals  Health Spending  Pollution  \
# 0       119   59687  73205  ...         21            11064        6.4
# 1      1533   42334  45219  ...        101             7281        8.1
# 2       732   42566  42454  ...         88             7408        7.1
# 3      1559   43650  48055  ...         83             6452        9.7
# 4      7338   62586  74205  ...        359             7549       12.8
#
#    Med-Large Airports  Temperature  Urban  Age 0-25  Age 26-54  Age 55+  \
# 0                 1.0         26.6   66.0      0.36       0.39     0.25
# 1                 1.0         62.8   59.0      0.33       0.37     0.31
# 2                 0.0         60.4   56.2      0.34       0.37     0.30
# 3                 1.0         60.3   89.8      0.33       0.36     0.30
# 4                 9.0         59.4   95.0      0.33       0.40     0.26
#
#    School Closure Date
# 0             03/19/20
# 1             03/16/20
# 2             03/17/20
# 3             03/16/20
# 4             03/19/20
#
# [5 rows x 26 columns]

# %% [markdown]
# # Step 2
# ### Get 20 data items as sample randomly and show them.

# %%
data.head(20)
# Out:
#                    State  Tested  Infected  Deaths  Population  Pop Density  \
# 0                 Alaska    5022       171     5.0      734002       1.2863
# 1                Alabama   13078      1676    45.0     4908621      96.9221
# 2               Arkansas   11143       819    14.0     3038999      58.4030
# 3                Arizona   27160      2019    52.0     7378494      64.9550
# 4             California  126700     12026   276.0    39937489     256.3727
# 5               Colorado   23900      4565   126.0     5845526      56.4011
# 6            Connecticut   22029      5276   165.0     3563077     735.8689
# 7   District of Columbia    6438       902    21.0      720687   11814.5410
# 8               Delaware    4289       593    14.0      982895     504.3073
# 9                Florida  114580     12151   218.0    21992985     410.1256
# 10               Georgia   26294      6383   208.0    10736059     186.6719
# 11                Hawaii   10462       351     3.0     1412687     219.9419
# 12                  Iowa   10240       786    14.0     3179849      56.9284
# 13                 Idaho    8870      1077    10.0     1826156      22.0969
# 14              Illinois   53581     10357   243.0    12659682     228.0243
# 15               Indiana   22652      4411   127.0     6745354     188.2810
# 16                Kansas    7578       698    21.0     2910357      35.5968
# 17              Kentucky   16663       917    40.0     4499692     113.9566
# 18             Louisiana   58498     12496   409.0     4645184     107.5175
# 19         Massachusetts   68800     11736   216.0     6976597     894.4355
#
#       Gini  ICU Beds  Income     GDP  ...  Hospitals  Health Spending  \
# 0   0.4081       119   59687   73205  ...         21            11064
# 1   0.4847      1533   42334   45219  ...        101             7281
# 2   0.4719       732   42566   42454  ...         88             7408
# 3   0.4713      1559   43650   48055  ...         83             6452
# 4   0.4899      7338   62586   74205  ...        359             7549
# 5   0.4586      1597   56846   63882  ...         89             6804
# 6   0.4945       674   74561   76342  ...         32             9859
# 7   0.5420       314   47285  200277  ...         10            11944
# 8   0.4522       186   51449   77253  ...          7            10254
# 9   0.4852      5604   49417   48318  ...        217             8076
# 10  0.4813      2508   45745   55832  ...        145             6587
# 11  0.4420       201   54565   64096  ...         22             7299
# 12  0.4451       545   48823   59977  ...        118             8200
# 13  0.4503       314   43155   43430  ...         45             6927
# 14  0.4810      3144   56933   67268  ...        187             8262
# 15  0.4527      1861   46646   55172  ...        132             8300
# 16  0.4550       767   50155   56334  ...        139             7651
# 17  0.4813      1392   41779   46898  ...        105             8004
# 18  0.4990      1289   45542   53589  ...        158             7815
# 19  0.4786      1326   70073   82480  ...         75            10559
#
#     Pollution  Med-Large Airports  Temperature  Urban  Age 0-25  Age 26-54  \
# 0         6.4                 1.0        26.60   66.0      0.36       0.39
# 1         8.1                 1.0        62.80   59.0      0.33       0.37
# 2         7.1                 0.0        60.40   56.2      0.34       0.37
# 3         9.7                 1.0        60.30   89.8      0.33       0.36
# 4        12.8                 9.0        59.40   95.0      0.33       0.40
# 5         6.7                 1.0        45.10   86.2      0.33       0.40
# 6         7.2                 1.0        49.00   88.0      0.30       0.38
# 7         9.8                 0.0        54.65  100.0      0.30       0.48
# 8         8.3                 0.0        55.30   83.3      0.30       0.37
# 9         7.4                 7.0        70.70   91.2      0.29       0.37
# 10        8.3                 1.0        63.50   75.1      0.35       0.39
# 11        5.4                 2.0        70.00   91.9      0.30       0.37
# 12        7.1                 0.0        47.80   64.0      0.34       0.36
# 13        6.8                 0.0        44.40   70.6      0.36       0.36
# 14        9.3                 2.0        51.80   88.5      0.33       0.38
# 15        8.4                 1.0        51.70   72.4      0.34       0.37
# 16        7.0                 0.0        54.30   74.2      0.35       0.36
# 17        8.1                 1.0        55.60   58.4      0.33       0.38
# 18        7.9                 1.0        66.40   73.2      0.34       0.37
# 19        6.3                 1.0        47.90   92.0      0.30       0.39
#
#     Age 55+  School Closure Date
# 0      0.25             03/19/20
# 1      0.31             03/16/20
# 2      0.30             03/17/20
# 3      0.30             03/16/20
# 4      0.26             03/19/20
# 5      0.27             03/23/20
# 6      0.32             03/17/20
# 7      0.22             03/16/20
# 8      0.33             03/16/20
# 9      0.35             03/16/20
# 10     0.26             03/18/20
# 11     0.32             03/23/20
# 12     0.30                  NaN
# 13     0.28             03/23/20
# 14     0.28             03/17/20
# 15     0.29             03/19/20
# 16     0.29             03/18/20
# 17     0.30             03/16/20
# 18     0.28             03/16/20
# 19     0.31             03/17/20
#
# [20 rows x 26 columns]

# %% [markdown]
# # Step 3
# ### Show 10 data items which the Deaths are more than 100 as sample randomly.

# %%
data[data['Deaths']>100].head(10)
# Out:
#             State  Tested  Infected  Deaths  Population  Pop Density    Gini  \
# 4      California  126700     12026   276.0    39937489     256.3727  0.4899
# 5        Colorado   23900      4565   126.0     5845526      56.4011  0.4586
# 6     Connecticut   22029      5276   165.0     3563077     735.8689  0.4945
# 9         Florida  114580     12151   218.0    21992985     410.1256  0.4852
# 10        Georgia   26294      6383   208.0    10736059     186.6719  0.4813
# 14       Illinois   53581     10357   243.0    12659682     228.0243  0.4810
# 15        Indiana   22652      4411   127.0     6745354     188.2810  0.4527
# 18      Louisiana   58498     12496   409.0     4645184     107.5175  0.4990
# 19  Massachusetts   68800     11736   216.0     6976597     894.4355  0.4786
# 22       Michigan   40465     14225   540.0    10045029     177.6655  0.4695
#
#     ICU Beds  Income    GDP  ...  Hospitals  Health Spending  Pollution  \
# 4       7338   62586  74205  ...        359             7549       12.8
# 5       1597   56846  63882  ...         89             6804        6.7
# 6        674   74561  76342  ...         32             9859        7.2
# 9       5604   49417  48318  ...        217             8076        7.4
# 10      2508   45745  55832  ...        145             6587        8.3
# 14      3144   56933  67268  ...        187             8262        9.3
# 15      1861   46646  55172  ...        132             8300        8.4
# 18      1289   45542  53589  ...        158             7815        7.9
# 19      1326   70073  82480  ...         75            10559        6.3
# 22      2423   47582  53209  ...        144             8055        8.0
#
#     Med-Large Airports  Temperature  Urban  Age 0-25  Age 26-54  Age 55+  \
# 4                  9.0         59.4   95.0      0.33       0.40     0.26
# 5                  1.0         45.1   86.2      0.33       0.40     0.27
# 6                  1.0         49.0   88.0      0.30       0.38     0.32
# 9                  7.0         70.7   91.2      0.29       0.37     0.35
# 10                 1.0         63.5   75.1      0.35       0.39     0.26
# 14                 2.0         51.8   88.5      0.33       0.38     0.28
# 15                 1.0         51.7   72.4      0.34       0.37     0.29
# 18                 1.0         66.4   73.2      0.34       0.37     0.28
# 19                 1.0         47.9   92.0      0.30       0.39     0.31
# 22                 1.0         44.4   74.6      0.32       0.37     0.31
#
#     School Closure Date
# 4              03/19/20
# 5              03/23/20
# 6              03/17/20
# 9              03/16/20
# 10             03/18/20
# 14             03/17/20
# 15             03/19/20
# 18             03/16/20
# 19             03/17/20
# 22             03/16/20
#
# [10 rows x 26 columns]

# %% [markdown]
# # Step 4
# ### Sort the data by GDP and present the top 20 data items.

# %%
data.sort_values(by='GDP',ascending=False).head(20)
# Out:
#                    State  Tested  Infected  Deaths  Population  Pop Density  \
# 7   District of Columbia    6438       902    21.0      720687   11814.5410
# 34              New York  283621    113704  3565.0    19440469     412.5211
# 19         Massachusetts   68800     11736   216.0     6976597     894.4355
# 8               Delaware    4289       593    14.0      982895     504.3073
# 6            Connecticut   22029      5276   165.0     3563077     735.8689
# 4             California  126700     12026   276.0    39937489     256.3727
# 47            Washington    5844       461    20.0     7797095     117.3272
# 0                 Alaska    5022       171     5.0      734002       1.2863
# 28          North Dakota    6207       186     3.0      761723      11.0393
# 50               Wyoming    8838       324     3.0      567025       5.8400
# 31            New Jersey   75356     34124   846.0     8936574    1215.1991
# 20              Maryland   28337      3609    67.0     6083116     626.6731
# 14              Illinois   53581     10357   243.0    12659682     228.0243
# 23             Minnesota   25423       865    24.0     5700671      71.5922
# 11                Hawaii   10462       351     3.0     1412687     219.9419
# 29              Nebraska    5472       323     8.0     1952570      25.4161
# 5               Colorado   23900      4565   126.0     5845526      56.4011
# 30         New Hampshire    8032       621     9.0     1371246     153.1605
# 45              Virginia   28043      1428     8.0     8626207     218.4403
# 38          Pennsylvania   70030     10017   136.0    12820878     286.5449
#
#       Gini  ICU Beds  Income     GDP  ...  Hospitals  Health Spending  \
# 7   0.5420       314   47285  200277  ...         10            11944
# 34  0.5229      3952   68667   85746  ...        166             9778
# 19  0.4786      1326   70073   82480  ...         75            10559
# 8   0.4522       186   51449   77253  ...          7            10254
# 6   0.4945       674   74561   76342  ...         32             9859
# 4   0.4899      7338   62586   74205  ...        359             7549
# 47  0.4591      1265   60781   74182  ...         92             7913
# 0   0.4081       119   59687   73205  ...         21            11064
# 28  0.4533       238   54306   72597  ...         39             9851
# 50  0.4360       102   60095   69900  ...         29             8320
# 31  0.4813      1822   67609   69378  ...         82             8859
# 20  0.4499      1134   62914   68573  ...         50             8602
# 14  0.4810      3144   56933   67268  ...        187             8262
# 23  0.4496      1171   56374   64675  ...        127             8871
# 11  0.4420       201   54565   64096  ...         22             7299
# 29  0.4477       440   52110   63942  ...         93             8412
# 5   0.4586      1597   56846   63882  ...         89             6804
# 30  0.4304       242   61405   63067  ...         28             9589
# 45  0.4705      1654   56952   62563  ...         96             7556
# 38  0.4689      3169   55349   61594  ...        199             9258
#
#     Pollution  Med-Large Airports  Temperature  Urban  Age 0-25  Age 26-54  \
# 7         9.8                 0.0        54.65  100.0      0.30       0.48
# 34        6.6                 3.0        45.40   87.9      0.31       0.39
# 19        6.3                 1.0        47.90   92.0      0.30       0.39
# 8         8.3                 0.0        55.30   83.3      0.30       0.37
# 6         7.2                 1.0        49.00   88.0      0.30       0.38
# 4        12.8                 9.0        59.40   95.0      0.33       0.40
# 47        8.0                 1.0        48.30   84.1      0.31       0.40
# 0         6.4                 1.0        26.60   66.0      0.36       0.39
# 28        4.6                 0.0        40.40   59.9      0.35       0.37
# 50        5.0                 0.0        42.00   64.8      0.32       0.36
# 31        8.1                 1.0        52.70   94.7      0.31       0.38
# 20        7.7                 1.0        54.20   87.2      0.31       0.39
# 14        9.3                 2.0        51.80   88.5      0.33       0.38
# 23        6.6                 1.0        41.20   73.3      0.32       0.38
# 11        5.4                 2.0        70.00   91.9      0.30       0.37
# 29        7.1                 1.0        48.80   73.1      0.35       0.37
# 5         6.7                 1.0        45.10   86.2      0.33       0.40
# 30        4.4                 0.0        43.80   60.3      0.28       0.37
# 45        6.9                 2.0        55.10   75.5      0.33       0.38
# 38        9.2                 2.0        48.80   78.7      0.30       0.37
#
#     Age 55+  School Closure Date
# 7      0.22             03/16/20
# 34     0.30             03/18/20
# 19     0.31             03/17/20
# 8      0.33             03/16/20
# 6      0.32             03/17/20
# 4      0.26             03/19/20
# 47     0.29             03/17/20
# 0      0.25             03/19/20
# 28     0.28             03/16/20
# 50     0.31             03/20/20
# 31     0.30             03/18/20
# 20     0.29             03/16/20
# 14     0.28             03/17/20
# 23     0.30             03/18/20
# 11     0.32             03/23/20
# 29     0.29                  NaN
# 5      0.27             03/23/20
# 30     0.34             03/16/20
# 45     0.29             03/16/20
# 38     0.32             03/16/20
#
# [20 rows x 26 columns]

# %% [markdown]
# # Step 5
# ### Show the simple statistical information (mean, std, min, max, quartile1, quartile2, quartile3).

# %%
list_mean=data.mean(axis = 0)
list_std=data.std(axis = 0)
list_min=data.min(axis = 0)
list_max=data.max(axis = 0)
list_quartile1=data.quantile(.25)
list_quartile2=data.quantile(.5)
list_quartile3=data.quantile(.75)

# %%
list_quartile1
# Out:
# Tested                7.090500e+03
# Infected              6.595000e+02
# Deaths                1.400000e+01
# Population            1.802113e+06
# Pop Density           5.060485e+01
# Gini                  4.520500e-01
# ICU Beds              3.270000e+02
# Income                4.598100e+04
# GDP                   5.115600e+04
# Unemployment          2.850000e+00
# Sex Ratio             9.425160e-01
# Smoking Rate          1.475000e+01
# Flu Deaths            1.300000e+01
# Respiratory Deaths    3.480000e+01
# Physicians            5.656000e+03
# Hospitals             4.450000e+01
# Health Spending       7.390000e+03
# Pollution             6.650000e+00
# Med-Large Airports    0.000000e+00
# Temperature           4.530000e+01
# Urban                 6.540000e+01
# Age 0-25              3.050000e-01
# Age 26-54             3.700000e-01
# Age 55+               2.900000e-01
# Name: 0.25, dtype: float64

# %% [markdown]
# # Step 6 Use matplotlib show 2D images about data.
# [Matplotlib](https://matplotlib.org/)
# ### Plot the distribution of two class (1. GDP < 58000, 2. GDP >= 58000) of COVID-19 State Data using different colors and different  marker where x-axis is the Pollution and y-axis the Mortality-rate.

# %%
import matplotlib.pyplot as plt
import numpy as np

bigGDP=data[data["GDP"]<58000]
smallGDP=data[data["GDP"]>=58000]
bigMR=bigGDP['Deaths']/bigGDP['Infected']
smallMR=smallGDP['Deaths']/smallGDP['Infected']
# x=[bigGDP['Population'],smallGDP['Population']]
# y=[bigMR,smallMR]
labelList=['GDP<58000','GDP>=58000']


fig = plt.figure() 
ax1 = fig.add_subplot(111) 
#設定標題 
ax1.set_title('Scatter Plot') 
#設定X軸標籤 
plt.xlabel('Pollution') 
#設定Y軸標籤 
plt.ylabel('MR') 
color=['r','b']
ax1.scatter(bigGDP['Pollution'],bigMR,c='r',marker='s',label='GDP >= 58000')
ax1.scatter(smallGDP['Pollution'],smallMR,c='b',marker='o', label='GDP < 58000')

plt.legend( loc='upper right') 
#顯示所畫的圖 
plt.show()

# %% [markdown]
# # Step 7
# ### Show the proportion of three class of COVID-19 State Data using pie chart.
#
# **<font color = blue size=3> About the class: </font>** <p>
#  1、 Mortality-rate < 0.02 <p>
#  2、 Mortality-rate between 0.02 and 0.03 <p>
#  3、Mortality-rate > 0.03 <p>

# %%
data['MR']=data['Deaths']/data['Infected']
MR1=len(data[data['MR']<0.02]) #<0.02

MR3=len(data[data['MR']>0.03])#>0.03
MR2=len(data["MR"])-(MR3+MR1)#0.02~0.03
labels = 'MR<0.2', '0.02<=MR<=0.03', 'MR>0.03'



sizes = [MR1,MR2,MR3]
print(sizes)
print(MR1/(MR1+MR2+MR3))
print(MR2/(MR1+MR2+MR3))
print(MR3/(MR1+MR2+MR3))
colors = ['gold', 'yellowgreen', 'lightcoral']
explode = (0.1, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()
# Out:
# [18, 22, 11]
# 0.35294117647058826
# 0.43137254901960786
# 0.21568627450980393
